# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from scipy import stats

# %%
df = pd.read_csv('../input/hex-data/HEX-USD.csv')

# %%
df

# %%
df.info()

# %%
df.isnull().sum()

# %%
df = df.dropna(axis=0)

# %%
df.isna().sum()

# %%
df = df.drop_duplicates()

# %%
df.describe()

# %%
plt.figure(figsize=(10,8))
fig, ax = plt.subplots(3,2, figsize=(10,8))
sns.boxplot(y=df.Open,ax=ax[0,0],color='red')
sns.boxplot(y=df.High,ax=ax[0,1],color='green')
sns.boxplot(y=df.Low,ax=ax[1,0],color='blue')
sns.boxplot(y=df.Close,ax=ax[1,1],color='violet')
sns.boxplot(y=df['Adj Close'],ax=ax[2,0],color='purple')
sns.boxplot(y=df.Volume,ax=ax[2,1],color='yellow')

# %%
sns.scatterplot(df['Adj Close'],df['Volume'])

# %%
sns.lmplot(y='Adj Close',x='Volume',data=df)

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)

# %%
df = df.drop('Date',axis=1)

# %%
X = df[['Adj Close']]
y = df['Volume']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
predict = lr.predict(X_test)

# %%
lr.score(X_train,y_train)

# %%
sns.scatterplot(predict,y_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(predict,y_test)
mse

# %%
RMSE1 = np.sqrt(mse)

# %%
RMSE

# %%
lr.intercept_

# %%
lr.coef_

# %%
 model = -1.82821626e+08*df['Open'] + 1.18096115e+09*df['High'] + -9.27345992e+08*df['Low'] + 1.32605567e+06*df['Close'] + 1.32605567e+06*df['Volume']

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
rf_predict = rf.predict(X_test)

# %%
rf.score(X_train,y_train)

# %%
mse = mean_squared_error(rf_predict,y_test)
mse

# %%
RMSE2 = np.sqrt(mse)
RMSE2

# %%
RMSE1 > RMSE2

# %%
# Random Forest regressor gives better result
