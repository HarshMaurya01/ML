# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, Flatten, MaxPooling2D, Conv2D, BatchNormalization
from keras.models import Sequential
import os

# %%
path = '../input/the-complete-pokemon-images-data-set/Pokemon Dataset'

# %%
import os
df = os.path.join(path)
data = os.listdir(df)

# %%
plt.imshow(plt.imread('../input/the-complete-pokemon-images-data-set/Pokemon Dataset/abra.png'))

# %%
os.path.join(path)
# Out:
# '../input/the-complete-pokemon-images-data-set/Pokemon Dataset'

# %%
plt.imread('../input/the-complete-pokemon-images-data-set/Pokemon Dataset/abra.png').shape
# Out:
# (475, 475, 4)

# %%
count=0
for clas in data:
    count=count+len(os.listdir(df))
print(data)
print(count)
total=len(os.listdir(path))
print(total)
# Out:
# ['throh.png', 'samurott.png', 'venomoth.png', 'latios.png', 'shinx.png', 'durant.png', 'primarina.png', 'geodude.png', 'popplio.png', 'wingull.png', 'miltank.png', 'castform.png', 'squirtle.png', 'shaymin-land.png', 'raikou.png', 'guzzlord.png', 'tapu-bulu.png', 'mawile.png', 'gallade.png', 'patrat.png', 'froslass.png', 'nidoking.png', 'magnemite.png', 'brionne.png', 'cloyster.png', 'alcremie.png', 'spinarak.png', 'meloetta-aria.png', 'regidrago.png', 'exploud.png', 'vanillish.png', 'kubfu.png', 'scrafty.png', 'azelf.png', 'mew.png', 'toucannon.png', 'carkol.png', 'vivillon-meadow.png', 'dialga.png', 'cryogonal.png', 'venonat.png', 'cherrim-overcast.png', 'regigigas.png', 'ferroseed.png', 'butterfree.png', 'zarude.png', 'porygon.png', 'crabominable.png', 'tepig.png', 'dragonite.png', 'paras.png', 'scolipede.png', 'smeargle.png', 'dreepy.png', 'pichu.png', 'tropius.png', 'typhlosion.png', 'dartrix.png', 'masquerain.png', 'kecleon.png', 'breloom.png', 'raboot.png', 'inkay.png', 'krabby
# ...

# %%
df = '../input/the-complete-pokemon-images-data-set/Pokemon Dataset'

# %%
path = os.path.join(df)
dire = os.listdir(df)

# %%
i=0
for i in range(0,5):
    pic=plt.imshow(plt.imread(path+"/"+dire[i]))
#     fig, ax = plt.subplots(2,2)

# %%
datagen = ImageDataGenerator(rescale=1./255,
                            rotation_range=20,
                            width_shift_range=0.2,
                            height_shift_range=0.2,
                            horizontal_flip=True)

# %%
data_path = '../input/the-complete-pokemon-images-data-set'
data = datagen.flow_from_directory(data_path,target_size=(475,475))
# Out:
# Found 898 images belonging to 1 classes.

# %%
X,y = next(data)

# %%
model = Sequential()

# %%
model.add(Conv2D(32,(3,3),input_shape=(475,475,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 473, 473, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 236, 236, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 234, 234, 64)      18496
# _________________________________________________________________
# flatten (Flatten)            (None, 3504384)           0
# _________________________________________________________________
# dense (Dense)                (None, 64)                224280640
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# ...
# Total params: 224,300,097
# Trainable params: 224,300,097
# Non-trainable params: 0
# ...

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X,y, epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 9s 9s/step - loss: 0.6995 - accuracy: 0.3750
# Epoch 2/5
# 1/1 [==============================] - 8s 8s/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 3/5
# 1/1 [==============================] - 7s 7s/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 4/5
# 1/1 [==============================] - 7s 7s/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 5/5
# 1/1 [==============================] - 7s 7s/step - loss: 0.0000e+00 - accuracy: 1.0000

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),input_shape=(475,475,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 473, 473, 32)      896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 236, 236, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 234, 234, 64)      18496
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3504384)           0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                224280640
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# ...
# Total params: 224,300,097
# Trainable params: 224,300,097
# Non-trainable params: 0
# ...

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(data,epochs=2,verbose=1,batch_size=64)
# Out:
# Epoch 1/2
# 29/29 [==============================] - 216s 7s/step - loss: 0.1267 - accuracy: 0.8378
# Epoch 2/2
# 29/29 [==============================] - 236s 8s/step - loss: 0.0000e+00 - accuracy: 1.0000
